# %% [markdown]
# Product Analysis

# %%
import pandas as pd

data = {
    'Product_ID': range(101, 111),
    'Product_Name': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
    'Category': ['Gadgets', 'Gadgets', 'Gadgets', 'Gadgets', 'Gadgets', 'Electronics', 'Electronics', 'Electronics', 'Electronics', 'Electronics'],
    'Price': [19.99, 29.99, 39.99, 49.99, 59.99, 69.99, 79.99, 89.99, 99.99, 109.99],
    'Stock': [100, 150, 200, 250, 300, 350, 400, 450, 500, 550]   
}

df = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Price'], df['Stock'])
plt.show()
