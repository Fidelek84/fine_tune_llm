# %% [markdown]
# Product Analysis

# %%
import pandas as pd

data = {
    'Product_ID': range(201, 211),
    'Product_Name': [
        'Quantum Mouse', 'Ergo Keyboard', 'HD Webcam', 'Silent Fan', 'USB-C Hub',
        'Smartwatch Pro', 'Noise-Cancelling Hz', 'Portable SSD 1TB', 'Mesh Router', 'VR Headset Elite'
    ],
    'Category': [
        'Peripherals', 'Peripherals', 'Peripherals', 'Components', 'Peripherals',
        'Wearables', 'Audio', 'Storage', 'Networking', 'Gaming'
    ],
    'Price': [29.99, 75.00, 49.99, 19.50, 39.95, 199.99, 149.00, 129.99, 89.99, 499.00],
    'Stock': [250, 180, 320, 400, 290, 110, 150, 90, 210, 50]
}

df = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Price'], df['Stock'])
plt.show()
